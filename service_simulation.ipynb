# %% [markdown]
# # EV 물류 서비스 시뮬레이션
#
# 저장된 모델을 불러와 배차·노선·SOC·충전·ETA를 실행합니다. 모델을 학습하지 않습니다.
#
# 먼저 `model_training.ipynb`를 실행해 `models/energy_model.joblib`를 생성하세요.

# %%
from pathlib import Path
import joblib

MODEL_PATH = Path.cwd() / 'models' / 'energy_model.joblib'
if not MODEL_PATH.exists():
    raise FileNotFoundError('먼저 model_training.ipynb를 실행해 모델을 생성하세요.')
bundle = joblib.load(MODEL_PATH)
model = bundle['model']
metrics = bundle['metrics']
print(f'저장 모델 로드 완료: {MODEL_PATH}')
print(metrics)
print('서비스 계산 로직은 기존 0828.ipynb의 4장 이후 셀 또는 app/app.py를 사용하세요.')
